# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# #### Observation
# * As expected, the Temperature and Latitude have a strong correlation. Cities with higher latitude (Closer to the Equator) have a higher temperature.
# * There are almost None or so week correlation between Latitude vs Cloudiness, Latitude vs Wind Speed and Latitude vs Humidity in both hemispheres.
# * In this time of the year, wind speed in almost all cities is less than 12 mph in both hemispheres and there is only one city with higher wind speeds in Northern Hemisphere.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/CSV/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Setting the base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Using Imperal as Unit for Fahrenheit 
units = "imperal"

# Building partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# Setting up lists to hold reponse info
lat = []
lng = []
city_name = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
max_temp =[]
wind_speed = []
errors =[]

# Setting counters for Sets and Records
api_set = 1
api_record = 1


# Loop through the list of cities and perform a request for data on each
for index, city in enumerate(cities):
    
    # By each call, we will retrieve a set of 50 records
    if( index % 50 == 0 and index >= 50):
        api_set += 1
        api_record = 1
        
    # Filling the Lists if the city was found on the URL
    try:
        response = requests.get(query_url + city).json()
        time.sleep(1)
        city_name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        
        #print(f"Processing Record {api_record} of set {api_set} | {city}")
        print(f"\033[0;30;48m Processing Record \033[1;32;48m {api_record} \033[0;30;48m of set \033[1;32;48m {api_set} \033[0;30;48m | {city}")

        
        api_record +=1
        
    # Skipping if the city was not found    
    except:
        errors.append(city)
        print(f"\033[1;31;47m{city} \033[1;30;48m not found. Skipping...")
        pass

# To Know whether the Data Retrieval completed or not and how many cities were not found!
print("-----------------------------------------------------------")
print(f"\033[0;30;48m Data Retrieval Completed with \033[1;31;47m {len(errors)} \033[0;30;48m skipped cities.")
print("-----------------------------------------------------------")
# Out:
#  Processing Record  1  of set  1  | kristiansund
#  Processing Record  2  of set  1  | punta arenas
#  Processing Record  3  of set  1  | saint-pierre
#  Processing Record  4  of set  1  | jamestown
#  Processing Record  5  of set  1  | mount isa
#  Processing Record  6  of set  1  | ushuaia
#  Processing Record  7  of set  1  | hobart
#  Processing Record  8  of set  1  | cape town
#  Processing Record  9  of set  1  | tuktoyaktuk
#  Processing Record  10  of set  1  | beringovskiy
#  Processing Record  11  of set  1  | palmer
#  Processing Record  12  of set  1  | thompson
#  Processing Record  13  of set  1  | aykhal
#  Processing Record  14  of set  1  | provideniya
#  Processing Record  15  of set  1  | olafsvik
#  Processing Record  16  of set  1  | ternate
# rolim de moura  not found. Skipping...
#  Processing Record  17  of set  1  | butaritari
#  Processing Record  18  of set  1  | clyde river
# taburi  not found. Skipping...
#  Processing Record  19  of set  1  | puli
#  Processing Record  20  of set  1  | hithadhoo
# jinchengjiang  not found. Skipping...
#  Processing Record  21  of set  1  | smithers
#  Processing Record  22  of set  1  | kapaa
#  Processing Record  23  of set  1  | khatanga
#  Processing Record  24  of set  1  | tuatapere
#  Processing Record  25  of set  1  | necochea
#  Processing Record  26  of set  1  | saskylakh
#  Processing Record  27  of set  1  | harper
#  Processing Record  28  of set  1  | kurilsk
#  Processing Record  29  of set  1  | rikitea
#  Processing Record  30  of set  1  | huambo
#  Processing Record  31  of set  1  | hilo
#  Processing Record  32  of set  1  | avarua
#  Processing Record  33  of set  1  | waipawa
#  Processing Record  34  of set  1  | georgetown
#  Processing Record  35  of set  1  | ocos
#  Processing Record  36  of set  1  | kaitangata
#  Processing Record  37  of set  1  | fukue
#  Processing Record  38  of set  1  | new iberia
#  Processing Record  39  of set  1  | hermanus
#  Processing Record  40  of set  1  | verkhozim
#  Processing Record  41  of set  1  | otradnoye
#  Processing Record  42  of set  1  | namibe
#  Processing Record  43  of set  1  | new norfolk
#  Processing Record  44  of set  1  | saldanha
#  Processing Record  45  of set  1  | rudnichnyy
#  Processing Record  46  of set  1  | mataura
#  Processing Record  47  of set  1  | nemuro
#  Processing Record  1  of set  2  | tarakan
#  Processing Record  2  of set  2  | yellowknife
#  Processing Record  3  of set  2  | carnarvon
#  Processing Record  4  of set  2  | nova venecia
#  Processing Record  5  of set  2  | paamiut
#  Processing Record  6  of set  2  | albany
#  Processing Record  7  of set  2  | arraial do cabo
#  Processing Record  8  of set  2  | luderitz
#  Processing Record  9  of set  2  | katsuura
#  Processing Record  10  of set  2  | petropavlovsk-kamchatskiy
#  Processing Record  11  of set  2  | bandarbeyla
# taolanaro  not found. Skipping...
#  Processing Record  12  of set  2  | faanui
#  Processing Record  13  of set  2  | sartell
#  Processing Record  14  of set  2  | redmond
#  Processing Record  15  of set  2  | richards bay
#  Processing Record  16  of set  2  | chicama
#  Processing Record  17  of set  2  | kenai
#  Processing Record  18  of set  2  | yar-sale
#  Processing Record  19  of set  2  | rawson
#  Processing Record  20  of set  2  | talnakh
#  Processing Record  21  of set  2  | silvan
#  Processing Record  22  of set  2  | fort nelson
#  Processing Record  23  of set  2  | atuona
#  Processing Record  24  of set  2  | tasiilaq
#  Processing Record  25  of set  2  | qasigiannguit
#  Processing Record  26  of set  2  | faya
#  Processing Record  27  of set  2  | pevek
#  Processing Record  28  of set  2  | skjervoy
#  Processing Record  29  of set  2  | sinnamary
#  Processing Record  30  of set  2  | molteno
#  Processing Record  31  of set  2  | dikson
#  Processing Record  32  of set  2  | bredasdorp
#  Processing Record  33  of set  2  | salalah
#  Processing Record  34  of set  2  | samarai
#  Processing Record  35  of set  2  | naze
#  Processing Record  36  of set  2  | cherskiy
#  Processing Record  37  of set  2  | puerto ayora
#  Processing Record  38  of set  2  | port alfred
#  Processing Record  39  of set  2  | praia da vitoria
#  Processing Record  40  of set  2  | qaanaaq
#  Processing Record  41  of set  2  | san andres
#  Processing Record  42  of set  2  | buala
#  Processing Record  43  of set  2  | tairua
#  Processing Record  44  of set  2  | nouadhibou
#  Processing Record  45  of set  2  | portland
#  Processing Record  46  of set  2  | tautira
#  Processing Record  47  of set  2  | sassandra
#  Processing Record  48  of set  2  | takoradi
#  Processing Record  49  of set  2  | porbandar
#  Processing Record  1  of set  3  | half moon bay
#  Processing Record  2  of set  3  | norman wells
#  Processing Record  3  of set  3  | kotaparh
#  Processing Record  4  of set  3  | nizhniy kuranakh
#  Processing Record  5  of set  3  | mar del plata
# bargal  not found. Skipping...
# illoqqortoormiut  not found. Skipping...
#  Processing Record  6  of set  3  | lasa
#  Processing Record  7  of set  3  | kavaratti
#  Processing Record  8  of set  3  | severo-kurilsk
#  Processing Record  9  of set  3  | kurkino
# saleaula  not found. Skipping...
#  Processing Record  10  of set  3  | tiksi
#  Processing Record  11  of set  3  | alta floresta
#  Processing Record  12  of set  3  | san patricio
#  Processing Record  13  of set  3  | bilibino
#  Processing Record  14  of set  3  | nome
#  Processing Record  15  of set  3  | cidreira
#  Processing Record  16  of set  3  | venado tuerto
#  Processing Record  17  of set  3  | byron bay
#  Processing Record  18  of set  3  | rio gallegos
#  Processing Record  19  of set  3  | san rafael
#  Processing Record  20  of set  3  | nata
#  Processing Record  21  of set  3  | vaini
#  Processing Record  22  of set  3  | cedar city
#  Processing Record  23  of set  3  | yulara
#  Processing Record  24  of set  3  | barrow
#  Processing Record  25  of set  3  | northam
#  Processing Record  26  of set  3  | arman
#  Processing Record  27  of set  3  | ahipara
#  Processing Record  28  of set  3  | victor harbor
#  Processing Record  29  of set  3  | thinadhoo
#  Processing Record  30  of set  3  | busselton
#  Processing Record  31  of set  3  | kuryk
#  Processing Record  32  of set  3  | clarence town
#  Processing Record  33  of set  3  | ponta do sol
#  Processing Record  34  of set  3  | amahai
#  Processing Record  35  of set  3  | lagunas
#  Processing Record  36  of set  3  | avera
#  Processing Record  37  of set  3  | lagoa
#  Processing Record  38  of set  3  | victoria
#  Processing Record  39  of set  3  | sandwick
#  Processing Record  40  of set  3  | lebu
#  Processing Record  41  of set  3  | honningsvag
#  Processing Record  42  of set  3  | los llanos de aridane
#  Processing Record  43  of set  3  | chuy
#  Processing Record  44  of set  3  | lokosovo
#  Processing Record  45  of set  3  | itea
# jabiru  not found. Skipping...
#  Processing Record  46  of set  3  | bengkulu
#  Processing Record  1  of set  4  | carballo
#  Processing Record  2  of set  4  | chancay
#  Processing Record  3  of set  4  | conakry
# bolungarvik  not found. Skipping...
#  Processing Record  4  of set  4  | lavrentiya
#  Processing Record  5  of set  4  | port elizabeth
#  Processing Record  6  of set  4  | mozarlandia
#  Processing Record  7  of set  4  | kawambwa
# jujuy  not found. Skipping...
# marcona  not found. Skipping...
#  Processing Record  8  of set  4  | troitsko-pechorsk
# grand river south east  not found. Skipping...
#  Processing Record  9  of set  4  | mutoko
#  Processing Record  10  of set  4  | searcy
#  Processing Record  11  of set  4  | east london
#  Processing Record  12  of set  4  | bluff
#  Processing Record  13  of set  4  | te anau
#  Processing Record  14  of set  4  | ribeira grande
#  Processing Record  15  of set  4  | kalemie
#  Processing Record  16  of set  4  | gravdal
#  Processing Record  17  of set  4  | pisco
#  Processing Record  18  of set  4  | torbay
#  Processing Record  19  of set  4  | auki
#  Processing Record  20  of set  4  | jakar
#  Processing Record  21  of set  4  | kudahuvadhoo
#  Processing Record  22  of set  4  | farrukhabad
#  Processing Record  23  of set  4  | labuhan
#  Processing Record  24  of set  4  | saint george
#  Processing Record  25  of set  4  | geraldton
#  Processing Record  26  of set  4  | mareeba
# belushya guba  not found. Skipping...
#  Processing Record  27  of set  4  | tigil
#  Processing Record  28  of set  4  | wabana
#  Processing Record  29  of set  4  | kodiak
#  Processing Record  30  of set  4  | bangkalan
#  Processing Record  31  of set  4  | bethel
#  Processing Record  32  of set  4  | puerto quijarro
#  Processing Record  33  of set  4  | peniche
#  Processing Record  34  of set  4  | tacuarembo
#  Processing Record  35  of set  4  | rio grande
#  Processing Record  36  of set  4  | jilib
#  Processing Record  37  of set  4  | kavieng
#  Processing Record  38  of set  4  | cabo san lucas
#  Processing Record  39  of set  4  | baie-comeau
#  Processing Record  40  of set  4  | belyy yar
#  Processing Record  41  of set  4  | hasaki
#  Processing Record  42  of set  4  | biak
#  Processing Record  43  of set  4  | shelburne
#  Processing Record  44  of set  4  | sao joao da barra
# samusu  not found. Skipping...
#  Processing Record  1  of set  5  | presidencia roque saenz pena
#  Processing Record  2  of set  5  | san felipe
#  Processing Record  3  of set  5  | la ronge
#  Processing Record  4  of set  5  | port blair
#  Processing Record  5  of set  5  | ulcinj
# tarudant  not found. Skipping...
#  Processing Record  6  of set  5  | yagoua
#  Processing Record  7  of set  5  | shihezi
#  Processing Record  8  of set  5  | radhanpur
#  Processing Record  9  of set  5  | hambantota
#  Processing Record  10  of set  5  | lulindi
#  Processing Record  11  of set  5  | kulhudhuffushi
# barentsburg  not found. Skipping...
#  Processing Record  12  of set  5  | college
#  Processing Record  13  of set  5  | cayenne
#  Processing Record  14  of set  5  | behbahan
#  Processing Record  15  of set  5  | teya
#  Processing Record  16  of set  5  | salinopolis
#  Processing Record  17  of set  5  | antalaha
#  Processing Record  18  of set  5  | souillac
#  Processing Record  19  of set  5  | luganville
#  Processing Record  20  of set  5  | quang ngai
#  Processing Record  21  of set  5  | leningradskiy
#  Processing Record  22  of set  5  | tsiroanomandidy
#  Processing Record  23  of set  5  | nha trang
#  Processing Record  24  of set  5  | haines junction
# mentok  not found. Skipping...
#  Processing Record  25  of set  5  | mnogovershinnyy
#  Processing Record  26  of set  5  | fairbanks
#  Processing Record  27  of set  5  | saint-joseph
#  Processing Record  28  of set  5  | ampanihy
#  Processing Record  29  of set  5  | esil
#  Processing Record  30  of set  5  | ilulissat
# mys shmidta  not found. Skipping...
#  Processing Record  31  of set  5  | tiznit
#  Processing Record  32  of set  5  | ugoofaaru
#  Processing Record  33  of set  5  | evanston
#  Processing Record  34  of set  5  | itarema
#  Processing Record  35  of set  5  | myanaung
#  Processing Record  36  of set  5  | ukiah
# novoyegoryevskoye  not found. Skipping...
#  Processing Record  37  of set  5  | verkhnetulomskiy
#  Processing Record  38  of set  5  | inirida
#  Processing Record  39  of set  5  | kruisfontein
#  Processing Record  40  of set  5  | binzhou
#  Processing Record  41  of set  5  | mecca
#  Processing Record  42  of set  5  | vardo
#  Processing Record  43  of set  5  | mandalgovi
#  Processing Record  44  of set  5  | kyzyl-suu
#  Processing Record  45  of set  5  | port victoria
#  Processing Record  1  of set  6  | fostoria
#  Processing Record  2  of set  6  | kloulklubed
# attawapiskat  not found. Skipping...
#  Processing Record  3  of set  6  | broken hill
#  Processing Record  4  of set  6  | mayo
#  Processing Record  5  of set  6  | sawtell
#  Processing Record  6  of set  6  | san miguel
#  Processing Record  7  of set  6  | namatanai
#  Processing Record  8  of set  6  | umm lajj
#  Processing Record  9  of set  6  | kichera
#  Processing Record  10  of set  6  | esna
#  Processing Record  11  of set  6  | banugao
# miranorte  not found. Skipping...
#  Processing Record  12  of set  6  | coos bay
#  Processing Record  13  of set  6  | cap-aux-meules
#  Processing Record  14  of set  6  | castro
#  Processing Record  15  of set  6  | patna
#  Processing Record  16  of set  6  | bambous virieux
#  Processing Record  17  of set  6  | pirgos
#  Processing Record  18  of set  6  | camacha
#  Processing Record  19  of set  6  | moranbah
#  Processing Record  20  of set  6  | teguldet
#  Processing Record  21  of set  6  | kahului
#  Processing Record  22  of set  6  | fortuna
#  Processing Record  23  of set  6  | mozelos
#  Processing Record  24  of set  6  | saint-philippe
#  Processing Record  25  of set  6  | sokolo
#  Processing Record  26  of set  6  | san juan
#  Processing Record  27  of set  6  | tazovskiy
#  Processing Record  28  of set  6  | kamenka
#  Processing Record  29  of set  6  | carolina
#  Processing Record  30  of set  6  | at-bashi
#  Processing Record  31  of set  6  | gat
# cumaribo  not found. Skipping...
#  Processing Record  32  of set  6  | roma
#  Processing Record  33  of set  6  | novobelokatay
#  Processing Record  34  of set  6  | erenhot
#  Processing Record  35  of set  6  | abu zabad
# nizhneyansk  not found. Skipping...
#  Processing Record  36  of set  6  | eureka
#  Processing Record  37  of set  6  | umm kaddadah
#  Processing Record  38  of set  6  | almunecar
#  Processing Record  39  of set  6  | ostrovnoy
# amderma  not found. Skipping...
#  Processing Record  40  of set  6  | colac
#  Processing Record  41  of set  6  | balkanabat
#  Processing Record  42  of set  6  | svetlyy
# kraste  not found. Skipping...
#  Processing Record  43  of set  6  | zyryanka
# vaitupu  not found. Skipping...
#  Processing Record  1  of set  7  | onega
# karaul  not found. Skipping...
#  Processing Record  2  of set  7  | tateyama
# tsihombe  not found. Skipping...
# lolua  not found. Skipping...
#  Processing Record  3  of set  7  | steinbach
#  Processing Record  4  of set  7  | shamary
#  Processing Record  5  of set  7  | esperance
#  Processing Record  6  of set  7  | ilinskoye-khovanskoye
#  Processing Record  7  of set  7  | monze
#  Processing Record  8  of set  7  | ifanadiana
#  Processing Record  9  of set  7  | ulaanbaatar
# tumannyy  not found. Skipping...
#  Processing Record  10  of set  7  | bubaque
#  Processing Record  11  of set  7  | lompoc
#  Processing Record  12  of set  7  | wahiawa
#  Processing Record  13  of set  7  | agadez
#  Processing Record  14  of set  7  | shimoda
#  Processing Record  15  of set  7  | mahebourg
#  Processing Record  16  of set  7  | navlya
#  Processing Record  17  of set  7  | meadow lake
#  Processing Record  18  of set  7  | pacific grove
#  Processing Record  19  of set  7  | kibre mengist
#  Processing Record  20  of set  7  | cuenca
#  Processing Record  21  of set  7  | podor
#  Processing Record  22  of set  7  | baruun-urt
#  Processing Record  23  of set  7  | zemio
# samalaeulu  not found. Skipping...
#  Processing Record  24  of set  7  | sitka
#  Processing Record  25  of set  7  | poykovskiy
#  Processing Record  26  of set  7  | kirakira
#  Processing Record  27  of set  7  | kaniama
#  Processing Record  28  of set  7  | uruzgan
#  Processing Record  29  of set  7  | mayumba
#  Processing Record  30  of set  7  | matamoros
#  Processing Record  31  of set  7  | havoysund
#  Processing Record  32  of set  7  | laguna
# bokspits  not found. Skipping...
#  Processing Record  33  of set  7  | san cristobal
#  Processing Record  34  of set  7  | bilma
#  Processing Record  35  of set  7  | bacolod
#  Processing Record  36  of set  7  | airai
#  Processing Record  37  of set  7  | beira
#  Processing Record  38  of set  7  | srednekolymsk
#  Processing Record  39  of set  7  | santiago del estero
#  Processing Record  40  of set  7  | miquelon
#  Processing Record  41  of set  7  | sulangan
#  Processing Record  42  of set  7  | pochutla
#  Processing Record  43  of set  7  | high level
# utiroa  not found. Skipping...
#  Processing Record  1  of set  8  | coffs harbour
#  Processing Record  2  of set  8  | tukrah
#  Processing Record  3  of set  8  | kununurra
#  Processing Record  4  of set  8  | wentzville
#  Processing Record  5  of set  8  | coihaique
#  Processing Record  6  of set  8  | makakilo city
#  Processing Record  7  of set  8  | gazli
#  Processing Record  8  of set  8  | yenagoa
#  Processing Record  9  of set  8  | yining
#  Processing Record  10  of set  8  | berlevag
#  Processing Record  11  of set  8  | galesong
#  Processing Record  12  of set  8  | yashkul
#  Processing Record  13  of set  8  | parkes
#  Processing Record  14  of set  8  | abrau-dyurso
#  Processing Record  15  of set  8  | karlshamn
#  Processing Record  16  of set  8  | erzin
#  Processing Record  17  of set  8  | sao filipe
#  Processing Record  18  of set  8  | rjukan
#  Processing Record  19  of set  8  | chokurdakh
#  Processing Record  20  of set  8  | bukama
#  Processing Record  21  of set  8  | nyurba
#  Processing Record  22  of set  8  | azangaro
#  Processing Record  23  of set  8  | henties bay
#  Processing Record  24  of set  8  | wanning
#  Processing Record  25  of set  8  | floro
#  Processing Record  26  of set  8  | longyearbyen
#  Processing Record  27  of set  8  | junin
#  Processing Record  28  of set  8  | dunedin
#  Processing Record  29  of set  8  | mgandu
#  Processing Record  30  of set  8  | chara
#  Processing Record  31  of set  8  | batticaloa
#  Processing Record  32  of set  8  | katherine
#  Processing Record  33  of set  8  | great yarmouth
#  Processing Record  34  of set  8  | banda aceh
#  Processing Record  35  of set  8  | port hardy
#  Processing Record  36  of set  8  | kirovo-chepetsk
#  Processing Record  37  of set  8  | saint-francois
#  Processing Record  38  of set  8  | isangel
#  Processing Record  39  of set  8  | warrington
#  Processing Record  40  of set  8  | codrington
#  Processing Record  41  of set  8  | del rio
#  Processing Record  42  of set  8  | port shepstone
#  Processing Record  43  of set  8  | mount gambier
#  Processing Record  44  of set  8  | teeli
#  Processing Record  45  of set  8  | coahuayana
#  Processing Record  46  of set  8  | upernavik
#  Processing Record  47  of set  8  | hualmay
# alotau  not found. Skipping...
#  Processing Record  48  of set  8  | senneterre
#  Processing Record  49  of set  8  | malakal
#  Processing Record  1  of set  9  | aasiaat
#  Processing Record  2  of set  9  | russell
# karamea  not found. Skipping...
#  Processing Record  3  of set  9  | hua hin
#  Processing Record  4  of set  9  | praya
# malwan  not found. Skipping...
#  Processing Record  5  of set  9  | ishigaki
# cagayan de tawi-tawi  not found. Skipping...
# suao  not found. Skipping...
#  Processing Record  6  of set  9  | oranjemund
#  Processing Record  7  of set  9  | qadirpur ran
#  Processing Record  8  of set  9  | chumikan
#  Processing Record  9  of set  9  | kolaras
#  Processing Record  10  of set  9  | libreville
#  Processing Record  11  of set  9  | farafangana
#  Processing Record  12  of set  9  | obera
#  Processing Record  13  of set  9  | pedernales
#  Processing Record  14  of set  9  | semey
#  Processing Record  15  of set  9  | ancud
#  Processing Record  16  of set  9  | orsha
#  Processing Record  17  of set  9  | kampong thum
#  Processing Record  18  of set  9  | voskresenskoye
#  Processing Record  19  of set  9  | ust-ishim
#  Processing Record  20  of set  9  | hirara
#  Processing Record  21  of set  9  | qaqortoq
#  Processing Record  22  of set  9  | minab
# crab hill  not found. Skipping...
#  Processing Record  23  of set  9  | emerald
#  Processing Record  24  of set  9  | neiafu
#  Processing Record  25  of set  9  | lorengau
#  Processing Record  26  of set  9  | tabas
#  Processing Record  27  of set  9  | shenjiamen
# palabuhanratu  not found. Skipping...
#  Processing Record  28  of set  9  | jutai
#  Processing Record  29  of set  9  | soke
#  Processing Record  30  of set  9  | troyes
#  Processing Record  31  of set  9  | bridlington
#  Processing Record  32  of set  9  | pangody
#  Processing Record  33  of set  9  | nishihara
#  Processing Record  34  of set  9  | matara
#  Processing Record  35  of set  9  | staffanstorp
#  Processing Record  36  of set  9  | rurrenabaque
#  Processing Record  37  of set  9  | magistralnyy
#  Processing Record  38  of set  9  | giehun
#  Processing Record  39  of set  9  | kharan
#  Processing Record  40  of set  9  | kushmurun
#  Processing Record  41  of set  9  | churapcha
#  Processing Record  42  of set  9  | biltine
#  Processing Record  43  of set  9  | bucerias
#  Processing Record  44  of set  9  | sawakin
#  Processing Record  1  of set  10  | qandala
# meyungs  not found. Skipping...
#  Processing Record  2  of set  10  | solana beach
#  Processing Record  3  of set  10  | mountain home
#  Processing Record  4  of set  10  | guerrero
#  Processing Record  5  of set  10  | taoudenni
#  Processing Record  6  of set  10  | kendari
#  Processing Record  7  of set  10  | uvat
#  Processing Record  8  of set  10  | presidente epitacio
#  Processing Record  9  of set  10  | tucuman
#  Processing Record  10  of set  10  | ineu
#  Processing Record  11  of set  10  | padang
# louisbourg  not found. Skipping...
#  Processing Record  12  of set  10  | saquena
#  Processing Record  13  of set  10  | tatarskaya pishlya
#  Processing Record  14  of set  10  | upata
#  Processing Record  15  of set  10  | bahia blanca
#  Processing Record  16  of set  10  | lumphat
#  Processing Record  17  of set  10  | pecos
#  Processing Record  18  of set  10  | muisne
#  Processing Record  19  of set  10  | conde
#  Processing Record  20  of set  10  | aksehir
#  Processing Record  21  of set  10  | juneau
# rostaq  not found. Skipping...
#  Processing Record  22  of set  10  | vostok
#  Processing Record  23  of set  10  | discovery bay
#  Processing Record  24  of set  10  | krasnogorskiy
#  Processing Record  25  of set  10  | maniitsoq
#  Processing Record  26  of set  10  | wajir
#  Processing Record  27  of set  10  | lethem
#  Processing Record  28  of set  10  | tura
#  Processing Record  29  of set  10  | bolotnoye
#  Processing Record  30  of set  10  | santa isabel do rio negro
#  Processing Record  31  of set  10  | kingaroy
#  Processing Record  32  of set  10  | las juntas
#  Processing Record  33  of set  10  | khandagayty
#  Processing Record  34  of set  10  | flinders
#  Processing Record  35  of set  10  | la paz
#  Processing Record  36  of set  10  | luan
#  Processing Record  37  of set  10  | bara
#  Processing Record  38  of set  10  | fallon
#  Processing Record  39  of set  10  | nelson bay
#  Processing Record  40  of set  10  | coaraci
#  Processing Record  41  of set  10  | zhezkazgan
#  Processing Record  42  of set  10  | aswan
#  Processing Record  43  of set  10  | san jose
#  Processing Record  44  of set  10  | pontes e lacerda
#  Processing Record  45  of set  10  | ambilobe
#  Processing Record  46  of set  10  | jishou
#  Processing Record  47  of set  10  | tecoanapa
#  Processing Record  1  of set  11  | wagga wagga
#  Processing Record  2  of set  11  | ekibastuz
#  Processing Record  3  of set  11  | yumen
#  Processing Record  4  of set  11  | san quintin
#  Processing Record  5  of set  11  | toledo
#  Processing Record  6  of set  11  | mendi
#  Processing Record  7  of set  11  | synya
#  Processing Record  8  of set  11  | rhyl
#  Processing Record  9  of set  11  | tingo maria
#  Processing Record  10  of set  11  | belaya gora
#  Processing Record  11  of set  11  | coquimbo
#  Processing Record  12  of set  11  | singkang
#  Processing Record  13  of set  11  | togul
# sentyabrskiy  not found. Skipping...
#  Processing Record  14  of set  11  | fangshan
#  Processing Record  15  of set  11  | krasnosilka
#  Processing Record  16  of set  11  | tadine
#  Processing Record  17  of set  11  | micheweni
#  Processing Record  18  of set  11  | adre
#  Processing Record  19  of set  11  | vysokogornyy
#  Processing Record  20  of set  11  | evensk
#  Processing Record  21  of set  11  | lukovetskiy
#  Processing Record  22  of set  11  | the pas
#  Processing Record  23  of set  11  | oeiras
#  Processing Record  24  of set  11  | palmares do sul
# ciras  not found. Skipping...
# labutta  not found. Skipping...
#  Processing Record  25  of set  11  | bowen
#  Processing Record  26  of set  11  | cambridge
#  Processing Record  27  of set  11  | shu
# ruatoria  not found. Skipping...
#  Processing Record  28  of set  11  | beloha
#  Processing Record  29  of set  11  | dingle
#  Processing Record  30  of set  11  | aklavik
#  Processing Record  31  of set  11  | constitucion
#  Processing Record  32  of set  11  | deputatskiy
#  Processing Record  33  of set  11  | acapulco
#  Processing Record  34  of set  11  | saint-augustin
#  Processing Record  35  of set  11  | cockburn town
#  Processing Record  36  of set  11  | gigmoto
#  Processing Record  37  of set  11  | caravelas
#  Processing Record  38  of set  11  | jibuti
# ngukurr  not found. Skipping...
#  Processing Record  39  of set  11  | zhaotong
#  Processing Record  40  of set  11  | urucara
#  Processing Record  41  of set  11  | ust-maya
#  Processing Record  42  of set  11  | masalli
#  Processing Record  43  of set  11  | nikolskoye
#  Processing Record  44  of set  11  | acarau
# tabiauea  not found. Skipping...
#  Processing Record  1  of set  12  | bagdarin
#  Processing Record  2  of set  12  | nioro
#  Processing Record  3  of set  12  | sao joaquim
#  Processing Record  4  of set  12  | launceston
#  Processing Record  5  of set  12  | almaznyy
#  Processing Record  6  of set  12  | jalu
#  Processing Record  7  of set  12  | kilindoni
#  Processing Record  8  of set  12  | bud
#  Processing Record  9  of set  12  | hofn
#  Processing Record  10  of set  12  | tual
#  Processing Record  11  of set  12  | cervo
#  Processing Record  12  of set  12  | general roca
#  Processing Record  13  of set  12  | terney
#  Processing Record  14  of set  12  | tamandare
#  Processing Record  15  of set  12  | asau
#  Processing Record  16  of set  12  | luanda
#  Processing Record  17  of set  12  | tuy hoa
#  Processing Record  18  of set  12  | tombouctou
#  Processing Record  19  of set  12  | porto novo
#  Processing Record  20  of set  12  | esmeraldas
#  Processing Record  21  of set  12  | kabinda
#  Processing Record  22  of set  12  | atambua
#  Processing Record  23  of set  12  | pangnirtung
#  Processing Record  24  of set  12  | kokopo
#  Processing Record  25  of set  12  | huaiyuan
#  Processing Record  26  of set  12  | katobu
#  Processing Record  27  of set  12  | adzope
#  Processing Record  28  of set  12  | sovetskaya
#  Processing Record  29  of set  12  | marzuq
#  Processing Record  30  of set  12  | preston
#  Processing Record  31  of set  12  | kathu
#  Processing Record  32  of set  12  | aksu
# burkhala  not found. Skipping...
#  Processing Record  33  of set  12  | zabid
#  Processing Record  34  of set  12  | gizo
#  Processing Record  35  of set  12  | cap malheureux
#  Processing Record  36  of set  12  | galle
#  Processing Record  37  of set  12  | drexel heights
#  Processing Record  38  of set  12  | la union
#  Processing Record  39  of set  12  | ziro
#  Processing Record  40  of set  12  | tabligbo
#  Processing Record  41  of set  12  | punta cardon
#  Processing Record  42  of set  12  | mogadishu
#  Processing Record  43  of set  12  | elizabeth city
#  Processing Record  44  of set  12  | kabarnet
#  Processing Record  45  of set  12  | klaksvik
#  Processing Record  46  of set  12  | urdoma
#  Processing Record  47  of set  12  | nabire
#  Processing Record  48  of set  12  | marawi
#  Processing Record  49  of set  12  | digha
#  Processing Record  1  of set  13  | pedro juan caballero
#  Processing Record  2  of set  13  | pilar
#  Processing Record  3  of set  13  | pingliang
#  Processing Record  4  of set  13  | promyshlennaya
#  Processing Record  5  of set  13  | yerbogachen
#  Processing Record  6  of set  13  | ola
#  Processing Record  7  of set  13  | qingyuan
#  Processing Record  8  of set  13  | trinidad
#  Processing Record  9  of set  13  | margate
# yurya  not found. Skipping...
#  Processing Record  10  of set  13  | puerto escondido
# -----------------------------------------------------------
#  Data Retrieval Completed with  51  skipped cities.
# -----------------------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Creating a DataFrame from the gained Info
weather_df = pd.DataFrame({'City': city_name,
                           'Cloudiness': cloudiness,
                           'Country': country,
                           'Date': date,
                           'Humidity': humidity,
                           'Lat': lat,
                           'Lng': lng,
                           'Max Temp': max_temp,
                           'Wind Speed': wind_speed})

# Setting the name for index columns
weather_df.index.names= ["City_ID"]

# Saving the DataFrame as CSV
weather_df.to_csv(output_data_file, header = True, index = True)

# Displaying the DataFrame for the first 100 rows
weather_df.head(100)
# Out:
#                      City  Cloudiness Country        Date  Humidity    Lat  \
# City_ID
# 0            Kristiansund           0      NO  1589963947        62  63.11
# 1            Punta Arenas          94      CL  1589963948        92 -53.15
# 2            Saint-Pierre          20      RE  1589963950        61 -21.34
# 3               Jamestown           1      US  1589963732        50  42.10
# 4               Mount Isa          98      AU  1589963952        41 -20.73
# ...                   ...         ...     ...         ...       ...    ...
# 95              Porbandar           0      IN  1589963996        53  21.64
# 96          Half Moon Bay          90      US  1589963847        71  37.46
# 97           Norman Wells          40      CA  1589964061        95  65.28
# 98               Kotapārh          96      IN  1589964063         8  19.15
# 99       Nizhniy Kuranakh         100      RU  1589964064        35  58.84
#
#             Lng  Max Temp  Wind Speed
# City_ID
# 0          7.73    280.15        4.10
# 1        -70.92    272.15        1.50
# 2         55.48    298.15       10.30
# 3        -79.24    285.37        2.10
# 4        139.50    299.15        6.70
# ...         ...       ...         ...
# 95        69.61    308.15        4.10
# 96      -122.43    287.59        6.20
# 97      -126.83    273.15        3.10
# 98        82.35    312.74        8.01
# 99       125.49    289.14        2.98
#
# [100 rows x 9 columns]

# %%
# Finding the Date of getting Info
api_date= datetime.utcfromtimestamp(weather_df.iloc[0,3]).strftime('%Y-%m-%d')
api_date
# Out:
# '2020-05-20'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Setting  X and Y Axis
x = weather_df['Lat']
y = weather_df['Max Temp']

# Creating the Scatter Plot
plt.scatter( x , y, marker = 'o', facecolors = 'gold', edgecolors = 'navy' )

# Setting Title and Labels for X and Y axis
plt.title('City Latitude vs Max Temperature (F)'+ ' ('+ api_date + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

# Setting Limitation for X and Y axis
plt.xlim(min(x)-3, max(x)+3)
plt.ylim(min(y)-3, max(y)+3)

# Setting the grid and layout and saving the plot
plt.grid()
plt.tight_layout()
plt.savefig('output_data/Plots/latitude_temperature_plot.png')
plt.show()

# %% [markdown]
# ##### Explanation: cities closer to the equator (Latitude = 0 ) have higher temperatures

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Setting  X and Y Axis
x = weather_df['Lat']
y = weather_df['Humidity']

# Creating the Scatter Plot
plt.scatter( x , y, marker = 'o', facecolors = 'orange', edgecolors = 'green' )

# Setting Title and Labels for X and Y axis
plt.title('City Latitude vs Humidity (%)'+ ' ('+ api_date + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Setting Limitation for X and Y axis
plt.xlim(min(x)-3, max(x)+3)
plt.ylim(min(y)-3, max(y)+3)

# Setting the grid and layout and saving the plot
plt.grid()
plt.tight_layout()
plt.savefig('output_data/Plots/latitude_humidity_plot.png')
plt.show()

# %% [markdown]
# ##### Explanation: There is no significant relationship between Latitude and Humidity. In a given Latitude, there are some cities with a low percentage of Humidity and some with a higher percentage of Humidity.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Setting  X and Y Axis
x = weather_df['Lat']
y = weather_df['Cloudiness']

# Creating the Scatter Plot
plt.scatter( x , y, marker = 'o', facecolors = 'cyan', edgecolors = 'black' )

# Setting Title and Labels for X and Y axis
plt.title('City Latitude vs Cloudiness (%)'+ ' ('+ api_date + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Setting Limitation for X and Y axis
plt.xlim(min(x)-3, max(x)+3)
plt.ylim(min(y)-3, max(y)+3)

# Setting the grid and layout and saving the plot
plt.grid()
plt.tight_layout()
plt.savefig('output_data/Plots/latitude_cloudiness_plot.png')
plt.show()

# %% [markdown]
# ##### Explanation: There is no relation between Latitude and Cloudiness. Cities scattered all over the plot. Even in a given Latitude, there are some cities with a high percentage of cloudiness and some with a low percentage of cloudiness.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Setting  X and Y Axis
x = weather_df['Lat']
y = weather_df['Wind Speed']

# Creating the Scatter Plot
plt.scatter( x , y, marker = 'o', facecolors = 'pink', edgecolors = 'red' )

# Setting Title and Labels for X and Y axis
plt.title('City Latitude vs Wind Speed (mph)'+ ' ('+ api_date + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# Setting Limitation for X and Y axis
plt.xlim(min(x)-3, max(x)+3)
plt.ylim(min(y)-3, max(y)+3)

# Setting the grid and layout and saving the plot
plt.grid()
plt.tight_layout()
plt.savefig('output_data/Plots/latitude_wind_speed_plot.png')
plt.show()

# %% [markdown]
# ##### Explanation: There is almost no relation between Latitude and Wind Speed. Almost all the cities in the time of pulling this info, have almost the same range of the wind speed which is less than 15 mph and only one city is near 25.

# %% [markdown]
# ## Linear Regression

# %%
# Creating a function to create Linear Regression plots

def linear_regression(x_axis, y_axis, title, xlabel, ylabel, name):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    print(f"The linear regression model between {xlabel} & {ylabel} is ({line_eq})")
    print(f"The R squard is ({rvalue})")
    
    # Creating the Scatter Plot
    plt.scatter(x_axis,y_axis, facecolor = 'gold', edgecolor = 'navy')

    # Creating the Line Plot
    plt.plot(x_axis,regress_values,"red", linewidth = 2)

    # Setting Title, X and Y labels
    plt.title(title+ '\n' + ' ('+ api_date + ')')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    # Printing the linear regression model on the plot
    plt.annotate(line_eq,(min(x_axis)+2,max(y_axis)-2),fontsize=14,color="red")
   
    # Setting Limitation for X and Y axis
    plt.xlim(min(x_axis)-1, max(x_axis)+1)
    plt.ylim(min(y_axis)-1, max(y_axis)+1)

    plt.grid()
    plt.tight_layout()
    plt.savefig(f'output_data/Plots/{name}.png')
    plt.show()

# %%
# Creating the Northern Hemisphere
northern_hemisphere = weather_df[weather_df.Lat >=0]

# Saving the DataFrame as CSV
northern_hemisphere.to_csv('output_data/CSV/northern_hemisphere_data.csv', header = True, index =False)

# Displaying the Northern Hemisphere DataFrame
northern_hemisphere
# Out:
#                      City  Cloudiness Country        Date  Humidity    Lat  \
# City_ID
# 0            Kristiansund           0      NO  1589963947        62  63.11
# 3               Jamestown           1      US  1589963732        50  42.10
# 8             Tuktoyaktuk           2      CA  1589963956        94  69.45
# 9            Beringovskiy          99      RU  1589963957        96  63.05
# 10                 Palmer           1      US  1589963546        93  42.16
# ...                   ...         ...     ...         ...       ...    ...
# 554           Yerbogachën          31      RU  1589964622        32  61.28
# 555                   Ola          66      RU  1589964623        63  59.58
# 556              Qingyuan          75      CN  1589964624        83  23.70
# 558               Margate           0      GB  1589964626        87  51.38
# 559      Puerto Escondido          50      MX  1589964366        68  15.85
#
#             Lng  Max Temp  Wind Speed
# City_ID
# 0          7.73    280.15        4.10
# 3        -79.24    285.37        2.10
# 8       -133.04    265.29        1.77
# 9        179.32    271.92        6.09
# 10       -72.33    279.26        1.94
# ...         ...       ...         ...
# 554      108.01    291.72        4.84
# 555      151.28    279.38        1.79
# 556      113.03    303.71        4.00
# 558        1.39    294.82        2.24
# 559      -97.07    301.43        2.44
#
# [380 rows x 9 columns]

# %%
# Creating the Southern Hemisphere
southern_hemisphere = weather_df[weather_df.Lat < 0]

# Saving the DataFrame as CSV
southern_hemisphere.to_csv('output_data/CSV/southern_hemisphere_data.csv', header = True, index =False)

# Displaying the Southern Hemisphere DataFrame
southern_hemisphere
# Out:
#                           City  Cloudiness Country        Date  Humidity  \
# City_ID
# 1                 Punta Arenas          94      CL  1589963948        92
# 2                 Saint-Pierre          20      RE  1589963950        61
# 4                    Mount Isa          98      AU  1589963952        41
# 5                      Ushuaia          55      AR  1589963668        74
# 6                       Hobart          75      AU  1589963954        62
# ...                        ...         ...     ...         ...       ...
# 538                   La Unión           1      PE  1589964604        77
# 547                     Nabire          60      ID  1589964614        82
# 550       Pedro Juan Caballero          20      PY  1589964617        84
# 551                      Pilar          75      BR  1589964618        94
# 557      La Santisima Trinidad           0      BO  1589964625        93
#
#            Lat     Lng  Max Temp  Wind Speed
# City_ID
# 1       -53.15  -70.92    272.15        1.50
# 2       -21.34   55.48    298.15       10.30
# 4       -20.73  139.50    299.15        6.70
# 5       -54.80  -68.30    274.15        1.50
# 6       -42.88  147.33    285.37        4.10
# ...        ...     ...       ...         ...
# 538      -5.40  -80.75    293.69        4.51
# 547      -3.37  135.48    300.37        0.57
# 550     -22.55  -55.73    290.23        5.71
# 551      -9.60  -35.96    297.15        2.10
# 557     -14.83  -64.90    295.33        1.50
#
# [180 rows x 9 columns]

# %% [markdown]
# ### Another method of creating northern and southern hemispheres DataFrames
# * By writting the for and iterrows, we can find the DataFrame of North_Hemisphere and South_Hemisphere. But after that I found an easy way only with one line of coding, so I made this one as command

# %%
# columns= ['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
# northern_hemisphere = pd.DataFrame(columns = columns)
# southern_hemisphere = pd.DataFrame(columns = columns)

# for index , row in weather_df.iterrows():
#     if(row['Lat'] >= 0):
#         northern_hemisphere.loc[index, 'Lat']= row['Lat'] #greater than or equal to 0 degrees latitude
#         northern_hemisphere.loc[index, 'Lng']= row['Lng']
#         northern_hemisphere.loc[index, 'Max Temp']= row['Max Temp']
#         northern_hemisphere.loc[index, 'Humidity']= row['Humidity']
#         northern_hemisphere.loc[index, 'Cloudiness']= row['Cloudiness']
#         northern_hemisphere.loc[index, 'Wind Speed']= row['Wind Speed']
#     else:
#         southern_hemisphere.loc[index, 'Lat']= row['Lat'] #greater than or equal to 0 degrees latitude
#         southern_hemisphere.loc[index, 'Lng']= row['Lng']
#         southern_hemisphere.loc[index, 'Max Temp']= row['Max Temp']
#         southern_hemisphere.loc[index, 'Humidity']= row['Humidity']
#         southern_hemisphere.loc[index, 'Cloudiness']= row['Cloudiness']
#         southern_hemisphere.loc[index, 'Wind Speed']= row['Wind Speed']

# northern_hemisphere.head()
# northern_hemisphere.head()


#-------------------------------------------------------------------------------#
# Creating Northern Hemisphere DataFrames
# northern_hemisphere = pd.DataFrame({'Lat':north})
# final_northern_hemisphere = pd.merge(northern_hemisphere, weather_df, how='left', on= 'Lat')
# final_northern_hemisphere.to_csv('output_data/CSV/northern_hemisphere_data.csv')
# final_northern_hemisphere['City'].value_counts()

#-------------------------------------------------------------------------------#
# Creating Southern Hemisphere DataFrames
# southern_hemisphere = pd.DataFrame({'Lat':south})
# final_southern_hemisphere = pd.merge(southern_hemisphere, weather_df, how='left', on= 'Lat')
# final_southern_hemisphere.to_csv('output_data/CSV/southern_hemisphere_data.csv')
# final_southern_hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_regression(northern_hemisphere['Lat']
                  ,northern_hemisphere['Max Temp']
                  ,'Northern Hemisphere\n Max Temp (F) vs. Latitude Linear Regression'
                  ,'Latitude','Max Temperature (F)'
                  , 'northern_hemisphere_lat_temp')
# Out:
# The linear regression model between Latitude & Max Temperature (F) is (y = -0.41x + 307.75)
# The R squard is (-0.762786659414902)

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_regression(southern_hemisphere['Lat'],
                  southern_hemisphere['Max Temp'],
                  'Southern Hemisphere\n Max Temp (F) vs. Latitude Linear Regression','Latitude',
                  'Max Temperature (F)',
                  'southern_hemisphere_lat_temp')
# Out:
# The linear regression model between Latitude & Max Temperature (F) is (y = 0.41x + 301.6)
# The R squard is (0.7392055260927707)

# %% [markdown]
# #### Explanation:
# ##### In the Northern Hemisphere the slope of the linear regression is negative which means when the latitude is increasing and being close to the north pole, the temperature is lower and when it is near the equator, it is higher.
# ##### In the Southern Hemisphere, the slope is positive with the same amount as Northern Hemisphere.
# ##### Also based on the rvalues, -0.76 is Strong Negative Correlation for the Northern Hemisphere and 0.74 is Strong Positive Correlation for Southern Hemisphere as well.
# ##### We can say that there is a strong correlation between Latitude and Temperature in both hemispheres.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_regression(northern_hemisphere['Lat'],
                  northern_hemisphere['Humidity'],
                  'Northern Hemisphere\n Humidity (%) vs. Latitude Linear Regression',
                  'Latitude','Humidity (%)',
                  'northern_hemisphere_lat_humidity')
# Out:
# The linear regression model between Latitude & Humidity (%) is (y = 0.06x + 60.78)
# The R squard is (0.05606382769054432)

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_regression(southern_hemisphere['Lat'],
                  southern_hemisphere['Humidity'],
                  'Southern Hemisphere\n Humidity (%) vs. Latitude Linear Regression',
                  'Latitude','Humidity (%)',
                  'southern_hemisphere_lat_humidity')
# Out:
# The linear regression model between Latitude & Humidity (%) is (y = 0.13x + 78.33)
# The R squard is (0.09375441647439568)

# %% [markdown]
# #### Explanation:
# ##### As expected in both hemispheres the amount of rvalue is less than 0.1  which shows None or Very Weak Correlation between Latitude and Humidity.
# ##### It is 0.06 for Northern Hemisphere and 0.09 for Southern Hemisphere.
# ##### There are different cities with different percentage of humidity around a given latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_regression(northern_hemisphere['Lat'],
                  northern_hemisphere['Cloudiness'],
                  'Northern Hemisphere\n Cloudiness (%) vs. Latitude Linear Regression',
                  'Latitude',
                  'Cloudiness (%)',
                  'northern_hemisphere_lat_cloudiness')
# Out:
# The linear regression model between Latitude & Cloudiness (%) is (y = -0.02x + 53.52)
# The R squard is (-0.01093451904402244)

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_regression(southern_hemisphere['Lat'],
                  southern_hemisphere['Cloudiness'],
                  'Southern Hemisphere\n Cloudiness (%) vs. Latitude Linear Regression',
                  'Latitude','Cloudiness (%)',
                  'southern_hemisphere_lat_cloudiness')
# Out:
# The linear regression model between Latitude & Cloudiness (%) is (y = -0.33x + 39.77)
# The R squard is (-0.11249370565061223)

# %% [markdown]
# #### Explanation:
# ##### As expected in both hemispheres the amount of rvalue is near 0.1  which shows None or Very Very Weak Correlation between Latitude and Cloudiness.
# ##### It is 0.01 for Northern Hemisphere and -0.11 for Southern Hemisphere.
# ##### There are different cities with different percentage of Cloudiness around a given latitude and cities are scattered all over the plot with a different percentage of cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_regression(northern_hemisphere['Lat'],
                  northern_hemisphere['Wind Speed'],
                  'Northern Hemisphere\n Wind Speed (mph) vs. Latitude Linear Regression',
                  'Latitude','Wind Speed (mph)',
                  'northern_hemisphere_lat_wind_speed')
# Out:
# The linear regression model between Latitude & Wind Speed (mph) is (y = -0.01x + 4.01)
# The R squard is (-0.04395311126973574)

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_regression(southern_hemisphere['Lat'],
                  southern_hemisphere['Wind Speed'],
                  'Southern Hemisphere\n Wind Speed (mph) vs. Latitude Linear Regression',
                  'Latitude','Wind Speed (mph)',
                  'southern_hemisphere_lat_wind_speed')
# Out:
# The linear regression model between Latitude & Wind Speed (mph) is (y = 0.0x + 3.57)
# The R squard is (0.024397567401265346)

# %% [markdown]
# #### Explanation:
# ##### The slope of linear regression on the southern hemisphere is negative but both of the slopes in both hemispheres are nearly 0 which means that the line plot is almost a straight line.
# ##### It means that in this time of the year, there are not big diffrences between the wind speeds in those cities or we can say all of them are below 12 mph except one city from the North Hemisphere!
# ##### The amount of rvalue is -0.04 for the North Hemisphere which shows None or Very Very Weak Negative Correlation between Latitude and Wind Speed as we expected.
# ##### It is 0.02 for Southern Hemisphere which shows the none or very very week correlation.
